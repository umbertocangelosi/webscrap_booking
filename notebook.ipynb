# %%
import pandas as pd
from src.scrap_oop import booking

# %%
# Create an instance of the booking class with the specified user agent in the headers
capaci = booking({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'})
# Out:
# Object booking created

# %%
# Set the parameters for the booking search
capaci.set('Paris', '2023-10-23', '2023-10-25', 4, 0)

# %%
# Initialize the parameters for the HTTP request
capaci.init_set()

# %%
# Get the hotel data
data = capaci.get_data()
# Out:
# Studio dans le 17ème, à 2km de Sacré Cœur
# 10
# € 348
# 17° arrondissement, Parigi
#
#
# -------
#
#
# Charming Duplex in PrivateStreet, Citycenter Paris
# null
# € 478
# 9° arrondissement, Parigi
#
#
# -------
#
#
# CMG Faubourg Saint Antoine- Bastille - 1
# 10
# € 585
# 12° arrondissement, Parigi
#
#
# -------
#
#
# Niepce 3eme Rose - Super appartement ensoleillé
# 10
# € 646
# 14° arrondissement, Parigi
#
#
# -------
#
#
# Eiffel Tower View - Cosy & Confortable - Paris2024
# null
# € 666
# 15° arrondissement, Parigi
#
#
# -------
#
#
# Appartement d'architecte au pied de Montmartre
# null
# € 720
# 18° arrondissement, Parigi
#
#
# -------
#
#
# Bright & Spacious apartment in Madeleine
# 10
# € 735
# 8° arrondissement, Parigi
#
#
# -------
#
#
# Appartement 2 pièces élégant proche Porte de Versailles
# 10
# € 770
# 15° arrondissement, Parigi
#
#
# -------
#
#
# Appartement luxueux avec salle de bains de rêve 6P
# 10
# € 819
# 17° arrondissement, Parigi
#
#
# -------
#
#
# ...

# %%
# Create a pandas DataFrame from the retrieved data
df = pd.DataFrame(data)
df
# Out:
#                                            hotel_name room_rate  price  \
# 0           Studio dans le 17ème, à 2km de Sacré Cœur        10  € 348
# 1   Charming Duplex in PrivateStreet, Citycenter P...      null  € 478
# 2            CMG Faubourg Saint Antoine- Bastille - 1        10  € 585
# 3     Niepce 3eme Rose - Super appartement ensoleillé        10  € 646
# 4   Eiffel Tower View - Cosy & Confortable - Paris...      null  € 666
# ..                                                ...       ...    ...
# 70                      Bohemian Flat - Lovely Marais       9,2  € 879
# 71  SUITE GIDE : au cœur de la Rive Gauche, neuf, ...       9,2  € 888
# 72                   Apartments Du Louvre - Le Marais       9,1  € 895
# 73                Appartement Tour Eiffel & Trocadéro      null  € 913
# 74  Amazing Apartment - 6 guests - 5 min from Gare...       9,1  € 937
#
#                       location checkin_date checkout_date
# ...
