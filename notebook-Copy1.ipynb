# %%
import pandas as pd
from src.scraper import booking
from src.generator import generator

# %%
# Create an instance of the booking class with the specified user agent in the headers
isola = booking({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'})
# Out:
# Object booking created

# %%
# Set the parameters for the booking search
generator(isola,'2023-06-5','2023-09-30',2, 'Capaci', 2, 0)
# Out:
# Case vacanze Vito e Alessia 96-01 Capaci PA
# 9,4
# € 120
# Capaci
#
#
# -------
#
#
# Casa Vacanze Ciccinè
# 9,3
# € 130
# Capaci
#
#
# -------
#
#
# il tramonto
# 9,2
# € 168
# Capaci
#
#
# -------
#
#
# villa nonna nina
# 9,2
# € 349
# Capaci
#
#
# -------
#
#
# La Casa di Peppe
# 8,8
# € 119
# Capaci
#
#
# -------
#
#
# Terra e Mare
# 8,8
# € 120
# Capaci
#
#
# -------
#
#
# Villa Salvatore
# 8,5
# € 196
# Capaci
#
#
# -------
#
#
# VILLA CHIARA 200 MT DA MARE SPIAGGIA LIBERA SABBIA
# 8,5
# € 450
# Capaci
#
#
# -------
#
#
# "La Piazza"di Nino&Daniela
# 8,3
# € 130
# Capaci
#
#
# -------
#
#
# Isole Luxury Apartments Isola delle femmine
# 8,0
# € 245
# Capaci
#
#
# -------
#
#
# ARIHOME
# null
# € 115
# Capaci
#
#
# -------
#
#
# ARIHOME
# null
# € 122
# Capaci
#
#
# -------
#
#
# Villa Paola
# null
# € 152
# Capaci
#
#
# -------
#
#
# BLU CAPACI
# null
# € 428
# Capaci
#
#
# -------
#
#
# Casa vacanza
# null
# € 570
# Capaci
#
#
# -------
#
#
# casa vacanza reale casetta
# 10
# ...

# %%
# Initialize the parameters for the HTTP request
capaci.init_set()

# %%
# Get the hotel data
dat = capaci.get_data()

# %%
isola.data

# %%
print(isola.data)

# %%
key = ['hotel_name','room_rate','price','location','checkin_date','checkout_date']

# %%
data = dict.fromkeys(key)

# %%
data

# %%
df = pd.DataFrame(isola.data)

# %%
df
# Out:
#                                         hotel_name room_rate  price  \
# 0      Case vacanze Vito e Alessia 96-01 Capaci PA       9,4  € 120
# 1                             Casa Vacanze Ciccinè       9,3  € 130
# 2                                      il tramonto       9,2  € 168
# 3                                 villa nonna nina       9,2  € 349
# 4                                 La Casa di Peppe       8,8  € 119
# ..                                             ...       ...    ...
# 95                            Casa vacanze bluchic       8,9  € 130
# 96                                    Casa Turramè       8,5  € 136
# 97  Casa vacanza a 11 km dall'aeroporto di Palermo       8,5  € 140
# 98       Le notti di Nettuno a Isola Delle Femmine       8,6  € 145
# 99                          Piano Monaco Apartment       8,8  € 151
#
#                location checkin_date checkout_date
# 0                Capaci   2023-06-05    2023-06-07
# ...

# %%
import pandas as pd
import os

def save_dict_to_excel(dictionary, filename, folder_path):
    filepath = os.path.join(folder_path, filename)
    df = pd.DataFrame.from_dict(dictionary)
    df.to_excel(filepath)

# Esempio di utilizzo

folder_path = os.path.abspath(os.path.join(os.getcwd()))
save_dict_to_excel(isola.data, 'output.xlsx', folder_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 12
#       9 # Esempio di utilizzo
#      11 folder_path = os.path.abspath(os.path.join(os.getcwd()))
# ---> 12 save_dict_to_excel(isola.data, 'output.xlsx', folder_path)
#
# Cell In[16], line 7, in save_dict_to_excel(dictionary, filename, folder_path)
#       5 filepath = os.path.join(folder_path, filename)
#       6 df = pd.DataFrame.from_dict(dictionary)
# ----> 7 df.to_excel(filepath)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...
